# %% [markdown]
# <a href="https://colab.research.google.com/github/snoop2head/study_in_yellow/blob/master/label_killer_hornets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/snoop2head/study_in_yellow
# Out:
# Cloning into 'study_in_yellow'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 17856 (delta 7), reused 12 (delta 3), pack-reused 17830
# Receiving objects: 100% (17856/17856), 681.02 MiB | 49.00 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Checking out files: 100% (17968/17968), done.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
from random import shuffle
import shutil
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image as img
from tensorflow.keras.models import Sequential

# %%
GITHUB_ROOT = './study_in_yellow/'
KILLER_ROOT = './study_in_yellow/asian-giant-hornet'
WASP_BEE_ROOT = './study_in_yellow/kaggle_bee_vs_wasp'

# %%
# Load model
model = tf.keras.models.load_model(f'./study_in_yellow/model')

# %%
from IPython.display import Image

# %%
def testing_image(image_directory): #testing out our model
    test_image = img.load_img(image_directory, target_size = (150, 150))
    test_image = img.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    result = model.predict(x = test_image)
    print(result)
    if result[0][2]==max(result[0]):
        print('Other than insects')
    elif result[0][1]==max(result[0]):
        print('Insects')
    elif result[0][0]==max(result[0]):
        print('Bees')
    else:
        print('oooo its the wasps')

# %%
Image(f'{KILLER_ROOT}/naver_0005.jpg')

# %%
testing_image(f'{KILLER_ROOT}/naver_0003.jpg')
# Out:
# [[0. 0. 0. 1.]]
# oooo its the wasps

# %%
test_file_name = "naver_0060"
test_file_path = f'{KILLER_ROOT}/{test_file_name}.jpg'
hornet_image = Image(test_file_path)
hornet_image

# %%
testing_image(test_file_path)
# Out:
# [[0.0000000e+00 1.0000000e+00 0.0000000e+00 5.3087385e-36]]
# Insects
